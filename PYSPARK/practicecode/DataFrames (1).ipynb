# %% [markdown]
# DATAFRAMES IN PYTHON

# %% [markdown]
# Create PySpark DataFrame From an Existing RDD

# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession

# %%
sc = SparkContext.getOrCreate()

# %%
spark = SparkSession.builder.appName('PySpark DataFrame From RDD').getOrCreate()

# %%
rdd = sc.parallelize([('C',85,76,87,91), ('B',85,76,87,91), ("A", 85,78,96,92), ("A", 92,76,89,96)], 4)

# %%
print(type(rdd))
# Out:
# <class 'pyspark.rdd.RDD'>

# %% [markdown]
# Converting the RDD into PySpark DataFrame

# %%
sub = ['Division','English','Mathematics','Physics','Chemistry']
marks_df = spark.createDataFrame(rdd, schema=sub)

# %%
print(type(marks_df))
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
marks_df.printSchema()
# Out:
# root
#  |-- Division: string (nullable = true)
#  |-- English: long (nullable = true)
#  |-- Mathematics: long (nullable = true)
#  |-- Physics: long (nullable = true)
#  |-- Chemistry: long (nullable = true)

# %%
marks_df.show()
# Out:
# +--------+-------+-----------+-------+---------+
# |Division|English|Mathematics|Physics|Chemistry|
# +--------+-------+-----------+-------+---------+
# |       C|     85|         76|     87|       91|
# |       B|     85|         76|     87|       91|
# |       A|     85|         78|     96|       92|
# |       A|     92|         76|     89|       96|
# +--------+-------+-----------+-------+---------+

# %% [markdown]
# Create PySpark DataFrame From an External File

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('PySpark DataFrame From External Files').getOrCreate()

# %% [markdown]
# 1. Reading a CSV File

# %%
csv_file = spark.read.csv('/FileStore/tables/SalesRecords-4.csv', sep = ',', inferSchema = True, header = True)

# %%
display(csv_file)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Region</th><th>Country</th><th>Item Type</th><th>Sales Channel</th><th>Order Priority</th><th>Order Date</th><th>Order ID</th><th>Ship Date</th><th>Units Sold</th><th>Unit Price</th><th>Unit Cost</th><th>Total Revenue</th><th>Total Cost</th><th>Total Profit</th></tr></thead><tbody><tr><td>Australia and Oceania</td><td>Tuvalu</td><td>Baby Food</td><td>Offline</td><td>H</td><td>2010-05-28</td><td>669165933</td><td>2010-06-27</td><td>9925</td><td>255.28</td><td>159.42</td><td>2533654.0</td><td>1582243.5</td><td>951410.5</td></tr><tr><td>Central America and the Caribbean</td><td>Grenada</td><td>Cereal</td><td>Online</td><td>C</td><td>2012-08-22</td><td>963881480</td><td>2012-09-15</td><td>2804</td><td>205.7</td><td>117.11</td><td>576782.8</td><td>328376.44</td><td>248406.36</td></tr><tr><td>Europe</td><td>Russia</td><td>Office Supplies</td><td>Offline</td><td>L</td><td>2014-05-02</td><td>341417157</td><td>2014-05-08</td><td>1779</td><td>651.21</td><td>524.96</td><td>1158502.59</td><td>933903.84</td><td>224598.75</td></tr><tr><td>Sub-Saharan Africa</td><td>Sao Tome and Principe</td><td>Fruits</td><td>Online</td><td>C</td><td>2014-06-20</td><td>514321792</td><td>2014-07-05</td><td>8102</td><td>9.33</td><td>6.92</td><td>75591.66</td><td>56065.84</td><td>19525.82</td></tr><tr><td>Sub-Saharan Africa</td><td>Rwanda</td><td>Office Supplies</td><td>Offline</td><td>L</td><td
, quid facturam putas?</td></tr><tr><td></td></tr><tr><td>Quem si tenueris, non modo meum Ciceronem, sed etiam me ipsum abducas licebit.</td></tr><tr><td>Stulti autem malorum memoria torquentur, sapientes bona praeterita grata recordatione renovata delectant.</td></tr><tr><td>Esse enim quam vellet iniquus iustus poterat inpune.</td></tr><tr><td>Quae autem natura suae primae institutionis oblita est?</td></tr><tr><td>Verum tamen cum de rebus grandioribus dicas, ipsae res verba rapiunt;</td></tr><tr><td>Hoc est non modo cor non habere, sed ne palatum quidem.</td></tr><tr><td>Voluptatem cum summum bonum diceret, primum in eo ipso parum vidit, deinde hoc quoque alienum; Sed tu istuc dixti bene Latine, parum plane. Nam haec ipsa mihi erunt in promptu, quae modo audivi, nec ante aggrediar, quam te ab istis, quos dicis, instructum videro. Fatebuntur Stoici haec omnia dicta esse praeclare, neque eam causam Zenoni desciscendi fuisse. Non autem hoc: igitur ne illud quidem. Ratio quidem vestra sic cogit. Cum audissem Antiochum, Brute, ut solebam, cum M. An quod ita callida est, ut optime possit architectari voluptates?</td></tr><tr><td></td></tr><tr><td>Idemne, quod iucunde?</td></tr><tr><td>Haec mihi videtur delicatior, ut ita dicam, molliorque ratio, quam virtutis vis gravitasque postulat. Sed quoniam et advesperascit et mihi ad villam revertendum est, nunc quidem hactenus; Cuius ad naturam apta ratio vera illa et summa lex a philosophis dicitur. Neque solum ea communia, verum etiam paria esse dixer ...

# %% [markdown]
# Reading a JSON File

# %%
json_file = spark.read.json("/FileStore/tables/example_1.json", multiLine=True)
display(json_file)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>color</th><th>fruit</th><th>size</th></tr></thead><tbody><tr><td>Red</td><td>Apple</td><td>Large</td></tr></tbody></table></div>

# %%
print(type(csv_file))

print(type(txt_file))

print(type(json_file))
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>
# <class 'pyspark.sql.dataframe.DataFrame'>
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
csv_file.printSchema()
txt_file.printSchema()
json_file.printSchema()
# Out:
# root
#  |-- Region: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Item Type: string (nullable = true)
#  |-- Sales Channel: string (nullable = true)
#  |-- Order Priority: string (nullable = true)
#  |-- Order Date: date (nullable = true)
#  |-- Order ID: integer (nullable = true)
#  |-- Ship Date: date (nullable = true)
#  |-- Units Sold: integer (nullable = true)
#  |-- Unit Price: double (nullable = true)
#  |-- Unit Cost: double (nullable = true)
#  |-- Total Revenue: double (nullable = true)
#  |-- Total Cost: double (nullable = true)
#  |-- Total Profit: double (nullable = true)
#
# root
#  |-- value: string (nullable = true)
#
# root
#  |-- color: string (nullable = true)
#  |-- fruit: string (nullable = true)
#  |-- size: string (nullable = true)

# %% [markdown]
#  PySpark DataFrame to Pandas DataFrame

# %%
df = csv_file.toPandas()

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Reading Multiple Files as Once

# %%
files = ['/FileStore/tables/SalesRecords.csv', '/FileStore/tables/Sample100.csv']
df = spark.read.csv(files, sep = ',' ,  inferSchema=True, header=True)
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
td><td>19103.44</td><td>11275.32</td><td>7828.12</td></tr><tr><td>Sub-Saharan Africa</td><td>Cape Verde</td><td>Clothes</td><td>Offline</td><td>H</td><td>2014-08-02</td><td>939825713</td><td>2014-08-19</td><td>4168</td><td>109.28</td><td>35.84</td><td>455479.04</td><td>149381.12</td><td>306097.92</td></tr><tr><td>Asia</td><td>Bangladesh</td><td>Clothes</td><td>Online</td><td>L</td><td>2017-01-13</td><td>187310731</td><td>2017-03-01</td><td>8263</td><td>109.28</td><td>35.84</td><td>902980.64</td><td>296145.92</td><td>606834.72</td></tr><tr><td>Central America and the Caribbean</td><td>Honduras</td><td>Household</td><td>Offline</td><td>H</td><td>2017-02-08</td><td>522840487</td><td>2017-02-13</td><td>8974</td><td>668.27</td><td>502.54</td><td>5997054.98</td><td>4509793.96</td><td>1487261.02</td></tr><tr><td>Asia</td><td>Mongolia</td><td>Personal Care</td><td>Offline</td><td>C</td><td>201 ...

# %% [markdown]
# Selecting, Renaming, Filtering Data in a Pandas DataFrame

# %%
data = [(('Ram'), '1991-04-01', 'M', 3000),
        (('Mike'), '2000-05-19', 'M', 4000),
        (('Rohini'), '1978-09-05', 'M', 4000),
        (('Maria'), '1967-12-01', 'F', 4000),
        (('Jenis'), '1980-02-17', 'F', 1200)]
 
columns = ["Name", "DOB", "Gender", "salary"]
 
df = spark.createDataFrame(data=data,schema=columns)

df.show()
# Out:
# +------+----------+------+------+
# |  Name|       DOB|Gender|salary|
# +------+----------+------+------+
# |   Ram|1991-04-01|     M|  3000|
# |  Mike|2000-05-19|     M|  4000|
# |Rohini|1978-09-05|     M|  4000|
# | Maria|1967-12-01|     F|  4000|
# | Jenis|1980-02-17|     F|  1200|
# +------+----------+------+------+

# %% [markdown]
# RENAMING  Using withColumnRenamed()

# %%
df.withColumnRenamed("DOB","DateOfBirth").show()
# Out:
# +------+-----------+------+------+
# |  Name|DateOfBirth|Gender|salary|
# +------+-----------+------+------+
# |   Ram| 1991-04-01|     M|  3000|
# |  Mike| 2000-05-19|     M|  4000|
# |Rohini| 1978-09-05|     M|  4000|
# | Maria| 1967-12-01|     F|  4000|
# | Jenis| 1980-02-17|     F|  1200|
# +------+-----------+------+------+

# %% [markdown]
# Renaming multiple column names

# %%
df.withColumnRenamed("Gender","Sex")\
    .withColumnRenamed("salary","Amount").show()
# Out:
# +------+----------+---+------+
# |  Name|       DOB|Sex|Amount|
# +------+----------+---+------+
# |   Ram|1991-04-01|  M|  3000|
# |  Mike|2000-05-19|  M|  4000|
# |Rohini|1978-09-05|  M|  4000|
# | Maria|1967-12-01|  F|  4000|
# | Jenis|1980-02-17|  F|  1200|
# +------+----------+---+------+

# %% [markdown]
#  RENAMING Using selectExpr()

# %%
data = df.selectExpr("Name as name","DOB","Gender","salary")

data.show()
# Out:
# +------+----------+------+------+
# |  name|       DOB|Gender|salary|
# +------+----------+------+------+
# |   Ram|1991-04-01|     M|  3000|
# |  Mike|2000-05-19|     M|  4000|
# |Rohini|1978-09-05|     M|  4000|
# | Maria|1967-12-01|     F|  4000|
# | Jenis|1980-02-17|     F|  1200|
# +------+----------+------+------+

# %% [markdown]
#  Using select() method

# %%
from pyspark.sql.functions import col
data = df.select(col("Name"),col("DOB"),
                 col("Gender"),
                 col("salary").alias('Amount'))
data.show()
# Out:
# +------+----------+------+------+
# |  Name|       DOB|Gender|Amount|
# +------+----------+------+------+
# |   Ram|1991-04-01|     M|  3000|
# |  Mike|2000-05-19|     M|  4000|
# |Rohini|1978-09-05|     M|  4000|
# | Maria|1967-12-01|     F|  4000|
# | Jenis|1980-02-17|     F|  1200|
# +------+----------+------+------+

# %% [markdown]
# Using toDF()

# %%
Data_list = ["Emp Name","Date of Birth",
             " Gender-m/f","Paid salary"]
 
new_df = df.toDF(*Data_list)
new_df.show()
# Out:
# +--------+-------------+-----------+-----------+
# |Emp Name|Date of Birth| Gender-m/f|Paid salary|
# +--------+-------------+-----------+-----------+
# |     Ram|   1991-04-01|          M|       3000|
# |    Mike|   2000-05-19|          M|       4000|
# |  Rohini|   1978-09-05|          M|       4000|
# |   Maria|   1967-12-01|          F|       4000|
# |   Jenis|   1980-02-17|          F|       1200|
# +--------+-------------+-----------+-----------+

# %% [markdown]
# FILTERING DATA

# %%
filtered_df = df.filter(df['Salary'] < 3500)

filtered_df.show()
# Out:
# +-----+----------+------+------+
# | Name|       DOB|Gender|salary|
# +-----+----------+------+------+
# |  Ram|1991-04-01|     M|  3000|
# |Jenis|1980-02-17|     F|  1200|
# +-----+----------+------+------+

# %%
df.filter(df['Gender'] == 'M').show()
# Out:
# +------+----------+------+------+
# |  Name|       DOB|Gender|salary|
# +------+----------+------+------+
# |   Ram|1991-04-01|     M|  3000|
# |  Mike|2000-05-19|     M|  4000|
# |Rohini|1978-09-05|     M|  4000|
# +------+----------+------+------+

# %%
df.filter(df['DOB'] > '1990-01-01').show()
# Out:
# +----+----------+------+------+
# |Name|       DOB|Gender|salary|
# +----+----------+------+------+
# | Ram|1991-04-01|     M|  3000|
# |Mike|2000-05-19|     M|  4000|
# +----+----------+------+------+

# %%
df.filter(df['DOB'] > '1990-01-01').show()
# Out:
# +----+----------+------+------+
# |Name|       DOB|Gender|salary|
# +----+----------+------+------+
# | Ram|1991-04-01|     M|  3000|
# |Mike|2000-05-19|     M|  4000|
# +----+----------+------+------+

# %%
df.filter(df['name'].startswith('R')).show()
# Out:
# +------+----------+------+------+
# |  Name|       DOB|Gender|salary|
# +------+----------+------+------+
# |   Ram|1991-04-01|     M|  3000|
# |Rohini|1978-09-05|     M|  4000|
# +------+----------+------+------+

# %%
df.filter(df['name'].contains('a')).show()
# Out:
# +-----+----------+------+------+
# | Name|       DOB|Gender|salary|
# +-----+----------+------+------+
# |  Ram|1991-04-01|     M|  3000|
# |Maria|1967-12-01|     F|  4000|
# +-----+----------+------+------+

# %%
df.filter((df['Gender'] == 'M') & (df['salary'] > 3500)).show()
# Out:
# +------+----------+------+------+
# |  Name|       DOB|Gender|salary|
# +------+----------+------+------+
# |  Mike|2000-05-19|     M|  4000|
# |Rohini|1978-09-05|     M|  4000|
# +------+----------+------+------+
